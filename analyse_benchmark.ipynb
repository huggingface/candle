# %%
import json
import os
import matplotlib.pyplot as plt

def try_parse_int(s, base=10, val=None):
  try:
    if s == None:
        return None
    return int(s, base)
  except ValueError:
    return val

# Function to parse criterion output
def parse_criterion_output(directory):
    data = []
    print(f"seach in {directory}")
    # Walk through the directory and read each JSON file
    for root, g, files in os.walk(directory):
        benchmark_group = None 
        for file in files:
            if "base" in root:
                continue
            if "matmul" in root:
                if file == "benchmark.json":
                    with open(os.path.join(root, file)) as f:
                        benchmark_data = json.load(f)
                        group =  benchmark_data['group_id']
                        func =  benchmark_data['function_id']

                        size =  try_parse_int(benchmark_data['value_str'])
                        throughput = benchmark_data['throughput']['Bytes']
                        benchmark_group = (group, size, throughput, func)
                if file == "estimates.json":
                    with open(os.path.join(root, file)) as f:
                        benchmark_data = json.load(f)
                        mean = benchmark_data['mean']['point_estimate']
                        if benchmark_group != None:
                            benchmark_group = (benchmark_group[0],benchmark_group[1],benchmark_group[2],benchmark_group[3],mean)
                            data.append(benchmark_group)

    return data


directory = './target/criterion/'
data = parse_criterion_output(directory)
# Out:
# seach in ./target/criterion/

# %%
# %matplotlib qt
# Function to generate comparison table
def generate_comparison_table(data):
    #group by group:
    groups = set(group for group, size, tp, func, mean in data)
    tables = []
    for group in groups:
     
        table = {}
        for g, size, tp, function_name, mean in data:
            if g == group:
                if size not in table:
                    table[size] = {}

                table[size][function_name] = mean

        print(f"Comparison Table {group}")
        print("Size\t", end="")
        functions = set(func for g, size, tp, func, mean in data if g == group)
        for function in functions:
            print(f"{function}\t", end="")
        print()
        
        for size, results in sorted(table.items()):
            print(f"{size}\t", end="")
            for function in functions:
                if function in results:
                    mean = results[function]
                    #print(f"{mean:.2f} ± {0:.2f}\t", end="")
                    print(f"{mean:.2f}\t", end="")
                else:
                    print("N/A\t", end="")
            print()
        tables.append((group, table))
    return tables

def print_best_results(data, index):
    groups = set(group for (group, size, tp, func, mean) in data)
    for group in groups:
        print(f"\nGroup: {group}")
        function_data = {}
        for (g, size, tp, function_name, mean) in [d for d in data if d[0] == group]:
            if function_name not in function_data:
                function_data[function_name] = {'sizes': [], 'means': [], 'tps': []}
            #if size in [1, 8, 32, 64, 128, 256, 512, 1024, 2048]:
            function_data[function_name]['sizes'].append(size)
            function_data[function_name]['means'].append(mean)
            function_data[function_name]['tps'].append(tp / mean)
        
        if len([function_name for function_name, metrics in function_data.items() if len(metrics['sizes']) > index]) == 0:
            continue

        tps_data = []
        size = 0
        for function_name, metrics in function_data.items():
            sizes = metrics['sizes']
            means = metrics['means']
            tps   = metrics['tps']
            dat = zip(sizes, means, tps)
            dat = sorted(dat, key=lambda x : x[0])
            sizes = [str(d[0]) for d in dat]
            means = [d[1] for d in dat]
            tps = [d[2] for d in dat]
            size = sizes[index]
            tps_data.append((function_name, tps[index]))

        print(f"(Size={size})")
        tps_map = sorted(tps_data, key=lambda x : x[1], reverse=True)
        
        for (name, tps) in tps_map:
            print(f"{name}: {tps}")


# Function to plot benchmark results
def plot_benchmark_results(data):
    groups = set(group for (group, size, tp, func, mean) in data)
    tables = []
    for group in groups:
    
        function_data = {}
        for (g, size, tp, function_name, mean) in [d for d in data if d[0] == group]:
            if function_name not in function_data:
                function_data[function_name] = {'sizes': [], 'means': [], 'tps': []}
            #if size in [1, 8, 32, 64, 128, 256, 512, 1024, 2048]:
            function_data[function_name]['sizes'].append(size)
            function_data[function_name]['means'].append(mean)
            function_data[function_name]['tps'].append(tp / mean)
        
        function_colors = {}
        c_counter = 0
        #colors = ["black", "red", "green", "blue", "yellow", "orange", "magenta", "cyan", "brown", "grey"]
        colors = plt.cm.tab20.colors

        if len([function_name for function_name, metrics in function_data.items() if len(metrics['sizes']) > 1]) == 0:
            continue

        plt.figure(figsize=(10, 14))
        for function_name, metrics in function_data.items():
            sizes = metrics['sizes']
            means = metrics['means']
            tps   = metrics['tps']
         
            dat = zip(sizes, means, tps)
            dat = sorted(dat, key=lambda x : x[0])
            sizes = [str(d[0]) for d in dat]
            means = [d[1] for d in dat]
            tps = [d[2] for d in dat]

            func = function_name.replace("_Prefetch", "")
            func = func.replace("_NoPadded", "")
            C = c_counter
            if func in function_colors:
                C = function_colors[func]
            else:
                function_colors[func] = C
                c_counter += 1
            #C = f"C{C}"
            C = colors[C]

            #std_devs = metrics['std_devs']
            #plt.errorbar(sizes, means, yerr=std_devs, label=function_name, capsize=5)
            if "Prefetch" in function_name and "NoPadded" in function_name:
                plt.plot(sizes, tps, "*--", label=function_name, color=C)
            elif "Prefetch" in function_name:
                plt.plot(sizes, tps, "--", label=function_name, color=C)
            elif "NoPadded" in function_name:
                plt.plot(sizes, tps, "*-", label=function_name, color=C)
            else: 
                plt.plot(sizes, tps, label=function_name, color=C)

        plt.xlabel('Size')
        plt.ylabel('Time (ns)')
        plt.ylabel('Throughput(Bytes)')
        plt.title(f'Benchmark Comparison {group}')
        #plt.xscale('log')
        plt.yscale('log')
        plt.legend()
        plt.grid(True)
        plt.show()


#run the analysis:
#comparison_table = generate_comparison_table(data)

print_best_results(data, 0)
plot_benchmark_results(data)


# Save comparison table to a file
# with open("benchmark_comparison_table.txt", "w") as f:
#     for (group, table) in comparison_table:
#         for size, results in sorted(table.items()):
#             f.write(f"{size}\t")
#             for function in table:
#                 if function in results:
#                     mean = results[function]
#                     #f.write(f"{mean:.2f} ± {0:.2f}\t")
#                     f.write(f"{mean:.2f}\t")
#                 else:
#                     f.write("N/A\t")
#             f.write("\n")
# Out:
# Group: matmul_(24x1536 * 1536x6144)
# (Size=None)
# wgpu_matmul_Matmul5_32_32(): 922.5797551910705
# wgpu_matmul_Matmul5_32_32(_Prefetch): 685.5685242363462
# wgpu_matmul_MatmulX: 656.4797558241759
# wgpu_matmul_Matmul5_16_16: 637.8123107537132
# wgpu_matmul_Matmul7: 587.0887150522702
# wgpu_matmul_Matuml5_64_64(): 535.9628438449554
# wgpu_matmul_Matuml5_64_64(_Prefetch): 466.20527097288476
# wgpu_matmul_Matmul1: 263.87447541311127
# wgpu_matmul_Matmul5_32_32(_NoPadded): 171.19553488461884
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 154.7785604754766
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 138.73582490895217
# wgpu_matmul_Matuml5_64_64(_NoPadded): 138.65328455427368
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 75.13673379128662
# wgpu_matmul_Matmul5_128_128(_NoPadded): 75.06937726037803
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 73.80776507714106
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 72.90763099679333
# wgpu_matmul_Matmul5_64_64_8_8(): 66.25237336813746
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 59.68718926965631
# wgpu_matmul_Matmul5_128_128(_Prefetch): 16.853885573911693
# wgpu_matmul_Matmul5_128_128(): 14.724641830597562
#
# Group: matmul_m_1
# (Size=1)
# cpu_matmul: 0.0005267141331699546
# wgpu_matmul_Matmul1: 0.0001288454860711719
# wgpu_matmul: 0.00012500489624992615
# wgpu_matmul_Matmul5_16_64(_Prefetch_NoPadded_LoadB): 0.00011932119310388701
# wgpu_matmul_Matmul5_16_64(_NoPadded_LoadB): 0.00011568123853428032
# wgpu_matmul_Matmul7: 0.00011228258312341074
# wgpu_matmul_Matmul5_1_128(_NoPadded_LoadB): 0.00010640909428930557
# wgpu_matmul_Matmul5_1_128(_NoPadded): 0.00010604459186312648
# wgpu_matmul_Matmul5_1_128(_Prefetch_NoPadded_LoadB): 9.244471595430437e-05
# wgpu_matmul_Matmul5_1_128(_Prefetch_NoPadded): 8.948796247740595e-05
# wgpu_matmul_Matmul5_16_16: 5.4616742031213215e-05
# wgpu_matmul_Matmul5_32_32(): 5.291229627724665e-05
# wgpu_matmul_Matmul5_16_64(_Prefetch_LoadB): 3.41699462738694e-05
# wgpu_matmul_Matuml5_64_64(): 3.247404959318747e-05
# wgpu_matmul_Matmul5_16_64(): 3.2082903876649345e-05
# wgpu_matmul_Matmul5_16_64(_LoadB): 3.1512185656775055e-05
# wgpu_matmul_Matmul5_64_64_8_8(): 3.023969252429278e-05
# wgpu_matmul_Matmul5_1_128(_Prefetch_LoadB): 2.9697001172535434e-05
# wgpu_matmul_Matmul5_1_128(_LoadB): 2.92010555817293e-05
# wgpu_matmul_Matmul5_1_128(): 2.641110272393558e-05
# wgpu_matmul_Matmul5_1_128(_Prefetch): 2.5246497182085238e-05
# wgpu_matmul_Matmul5_32_32(_LoadB): 2.431351269280499e-05
# wgpu_matmul_Matmul5_128_128(): 2.3370272813943028e-05
#
# Group: matmul_64*(64x1664 * 1664x2560)
# (Size=None)
# wgpu_matmul_Matmul5_64_64_8_8(): 2167.0725951107015
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1549.6070889201208
# wgpu_matmul_Matuml5_64_64(): 1472.2517871113241
# wgpu_matmul_MatmulX: 1467.8064584151198
# wgpu_matmul_Matmul5_32_32(): 1224.8448031392768
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1142.2804835932957
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 1121.3648973060126
# wgpu_matmul_Matmul7: 623.5424769058031
# wgpu_matmul_Matmul5_16_16: 500.28107568373537
# wgpu_matmul_Matmul1: 287.573055742059
# wgpu_matmul_Matmul5_32_32(_NoPadded): 235.75193045081423
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 221.40224304960785
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 132.49311355184102
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 102.62410152774237
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 82.83883704751918
# wgpu_matmul_Matuml5_64_64(_NoPadded): 55.595290493902624
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 51.508879731684985
# wgpu_matmul_Matmul5_128_128(_NoPadded): 50.526912654804384
# wgpu_matmul_Matmul5_128_128(_Prefetch): 33.65170808655829
# wgpu_matmul_Matmul5_128_128(): 23.639177971354677
#
# Group: matmul_48*(24x1536 * 1536x6144)
# (Size=None)
# wgpu_matmul_Matmul5_32_32(): 857.4171524564264
# wgpu_matmul_Matmul5_32_32(_Prefetch): 804.5636365688342
# wgpu_matmul_MatmulX: 792.2199759641687
# wgpu_matmul_Matuml5_64_64(_Prefetch): 553.8797205608207
# wgpu_matmul_Matuml5_64_64(): 552.5268191059049
# wgpu_matmul_Matmul7: 459.15411759830323
# wgpu_matmul_Matmul5_16_16: 378.90496451132276
# wgpu_matmul_Matmul1: 240.73561048993716
# wgpu_matmul_Matmul5_32_32(_NoPadded): 199.2333619023877
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 187.37894078102812
# wgpu_matmul_Matuml5_64_64(_NoPadded): 170.99883949054103
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 160.0450910050473
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 95.71844670005119
# wgpu_matmul_Matmul5_128_128(_NoPadded): 93.30355929820985
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 84.25495139527959
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 74.35141305862216
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 42.754033143473315
# wgpu_matmul_Matmul5_64_64_8_8(): 25.60063967949149
# wgpu_matmul_Matmul5_128_128(_Prefetch): 12.752586529063464
# wgpu_matmul_Matmul5_128_128(): 8.880006811541245
#
# Group: matmul_(2048x2048 * 2048x2048)
# (Size=None)
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedB: 2765.197725005138
# wgpu_matmul_MatmulX_tranposedB: 2697.913759664047
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA_tranposedB: 2571.86877880284
# wgpu_matmul_Matmul5_64_64_8_8(): 2531.0596407374983
# wgpu_matmul_MatmulX_tranposedA_tranposedB: 2486.9009397785035
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA: 2369.125946355068
# wgpu_matmul_MatmulX_tranposedA: 2343.529859854347
# wgpu_matmul_MatmulX: 2206.324424337016
# wgpu_matmul_Matmul5_64_128_8_8()_tranposedB: 1929.2642654836077
# wgpu_matmul_Matmul5_64_128_8_8()_tranposedA_tranposedB: 1892.9446983234145
# wgpu_matmul_Matmul5_128_128()_tranposedB: 1864.217287573033
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 1851.2886698054897
# wgpu_matmul_Matmul5_128_128()_tranposedA: 1823.322943880609
# wgpu_matmul_Matmul5_64_128_8_8(): 1722.482443785204
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1628.1122396555875
# wgpu_matmul_Matmul5_128_128(): 1609.900072227792
# wgpu_matmul_Matmul5_64_128_8_8()_tranposedA: 1598.0699933825051
# wgpu_matmul_Matmul5_128_128()_tranposedA_tranposedB: 1584.0064549215547
# wgpu_matmul_Matuml5_64_64()_tranposedB: 1524.1841984862838
# wgpu_matmul_Matmul5_128_128(_Prefetch): 1508.5555637547668
# wgpu_matmul_Matuml5_64_64(): 1493.4969088667276
# wgpu_matmul_Matuml5_64_64()_tranposedA_tranposedB: 1484.1120403555426
# wgpu_matmul_Matuml5_64_64()_tranposedA: 1430.7974110878447
# wgpu_matmul_Matuml5_64_128(): 1132.0114967251393
# wgpu_matmul_Matuml5_64_128()_tranposedB: 1131.5541871600678
# wgpu_matmul_Matuml5_64_128()_tranposedA_tranposedB: 1130.1015557166038
# wgpu_matmul_Matmul5_32_32()_tranposedA: 1116.6604049468497
# wgpu_matmul_Matuml5_64_128()_tranposedA: 1090.4147338176529
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1046.6636938774773
# wgpu_matmul_Matmul5_32_32()_tranposedA_tranposedB: 1025.6301544725397
# wgpu_matmul_Matmul5_32_32(): 998.3782112466048
# wgpu_matmul_Matmul5_32_32()_tranposedB: 949.0829321181977
# wgpu_matmul_Matmul5_16_16: 839.7197907038694
# wgpu_matmul_Matmul7: 835.8174811152477
# wgpu_matmul_Matmul7_tranposedB: 813.6809246415846
# wgpu_matmul_Matmul5_16_16_tranposedB: 813.5028862407225
# wgpu_matmul_Matmul7_tranposedA_tranposedB: 812.9968096967249
# wgpu_matmul_Matmul7_tranposedA: 812.3185652239226
# wgpu_matmul_Matmul5_16_16_tranposedA_tranposedB: 803.2567298073109
# wgpu_matmul_Matmul5_16_16_tranposedA: 794.3406657681973
# wgpu_matmul_Matmul1: 315.91065772621664
# wgpu_matmul_Matmul1_tranposedA: 314.43679083056537
# cpu_matmul_tranposedB: 290.61672042538964
# cpu_matmul: 289.824718335528
# cpu_matmul_tranposedA: 243.77244540175758
# cpu_matmul_tranposedA_tranposedB: 239.11583787739235
# wgpu_matmul_Matmul1_tranposedA_tranposedB: 86.91332841406725
# wgpu_matmul_Matmul1_tranposedB: 86.77923858593972
#
# Group: matmul_(32x2304 * 2304x5120)
# (Size=None)
# wgpu_matmul_Matmul5_32_32()_tranposedA: 1423.7642714396638
# wgpu_matmul_Matmul5_32_32()_tranposedA_tranposedB: 1419.4070308374958
# wgpu_matmul_Matmul5_32_32()_tranposedB: 1414.059053131282
# wgpu_matmul_Matmul5_32_32(_Prefetch): 943.0069718069312
# wgpu_matmul_Matmul5_32_32(): 935.0732445988629
# wgpu_matmul_Matuml5_64_64()_tranposedA: 857.3277418836476
# wgpu_matmul_Matuml5_64_64()_tranposedA_tranposedB: 841.4688011058662
# wgpu_matmul_Matuml5_64_64()_tranposedB: 841.3005860425353
# wgpu_matmul_Matmul5_16_16_tranposedA: 838.4342339634773
# wgpu_matmul_Matmul5_16_16_tranposedB: 780.0427953774595
# wgpu_matmul_Matmul5_16_16: 776.8638699721654
# wgpu_matmul_Matmul5_16_16_tranposedA_tranposedB: 772.4447710676668
# wgpu_matmul_Matuml5_64_64(): 769.3286381023668
# wgpu_matmul_Matmul7_tranposedA: 764.4442304931796
# wgpu_matmul_Matmul7_tranposedB: 730.2097354083708
# wgpu_matmul_Matmul7_tranposedA_tranposedB: 720.8930775396545
# wgpu_matmul_Matmul5_64_64_8_8(): 709.9299480991567
# wgpu_matmul_Matmul7: 705.6239491072624
# wgpu_matmul_Matmul5_64_128_8_8(): 588.6761458988245
# wgpu_matmul_Matuml5_64_64(_Prefetch): 521.5944378895548
# wgpu_matmul_MatmulX: 443.26002369444655
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 413.99143128225853
# wgpu_matmul_Matuml5_64_128(): 397.1070844293154
# wgpu_matmul_Matmul5_128_128(): 303.07524177397516
# wgpu_matmul_Matmul1_tranposedA: 290.7705932694407
# wgpu_matmul_Matmul1: 281.12088968136464
# wgpu_matmul_Matmul5_32_32(_NoPadded): 237.4062468337266
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 227.6898311109374
# wgpu_matmul_Matmul5_128_128(_Prefetch): 210.6463947129845
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 150.73358473894527
# wgpu_matmul_Matuml5_64_64(_NoPadded): 150.7038878746907
# cpu_matmul_tranposedB: 117.19288596390328
# cpu_matmul: 104.6681905350293
# cpu_matmul_tranposedA_tranposedB: 99.2714181025957
# cpu_matmul_tranposedA: 98.0408485470675
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedB: 94.3512651586817
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA_tranposedB: 93.57084070754473
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA: 92.79488873554857
# wgpu_matmul_Matmul1_tranposedB: 85.21396378728691
# wgpu_matmul_Matmul1_tranposedA_tranposedB: 84.5305499698145
# wgpu_matmul_Matmul5_128_128(_NoPadded): 81.97451244084378
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 81.72979187395407
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 80.75651662254165
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 79.73783013425187
# wgpu_matmul_Matmul5_128_128()_tranposedB: 21.613804598043583
# wgpu_matmul_Matmul5_128_128()_tranposedA_tranposedB: 21.597643560973502
# wgpu_matmul_Matmul5_128_128()_tranposedA: 21.55157156895699
#
# Group: matmul_(1101x1280 * 1280x1280)
# (Size=None)
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1424.2528850166805
# wgpu_matmul_Matuml5_64_64(): 1321.5539943678073
# wgpu_matmul_Matmul5_32_32(): 1217.1128445361162
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1141.1162548524194
# wgpu_matmul_Matmul7: 797.5507382969138
# wgpu_matmul_Matmul5_16_16: 673.0140878372965
# wgpu_matmul_Matmul1: 330.2365714593011
# wgpu_matmul_Matmul5_32_32(_NoPadded): 243.34360668826898
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 219.89533544222783
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 114.17055772263751
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 96.37835327966116
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 85.71349482366394
# wgpu_matmul_Matmul5_128_128(_Prefetch): 75.257720179328
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 70.44138515100742
# wgpu_matmul_Matuml5_64_64(_NoPadded): 63.92107129050801
# wgpu_matmul_Matmul5_64_64_8_8(): 62.62529257908932
# wgpu_matmul_MatmulX: 61.20160219733313
# wgpu_matmul_Matmul5_128_128(_NoPadded): 50.61912268712637
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 49.647348984150966
# wgpu_matmul_Matmul5_128_128(): 47.35395687076941
#
# Group: matmul_(64x2304 * 2304x5120)
# (Size=None)
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA_tranposedB: 1810.6322116037418
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedA: 1785.4599946207586
# wgpu_matmul_Matmul5_64_64_8_8()_tranposedB: 1770.3419140226952
# wgpu_matmul_Matuml5_64_64()_tranposedA: 1699.7738013305052
# wgpu_matmul_Matuml5_64_64()_tranposedA_tranposedB: 1676.8699565802392
# wgpu_matmul_Matuml5_64_64()_tranposedB: 1663.280247995397
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 1579.045415694896
# wgpu_matmul_Matuml5_64_64(): 1555.3835012003397
# wgpu_matmul_MatmulX: 1524.3342025860868
# wgpu_matmul_Matmul5_64_64_8_8(): 1461.8558275004223
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1433.3412263092841
# wgpu_matmul_Matmul5_32_32()_tranposedA: 1410.599689302462
# wgpu_matmul_Matmul5_32_32()_tranposedA_tranposedB: 1410.3734687032495
# wgpu_matmul_Matmul5_32_32()_tranposedB: 1406.9996037277142
# wgpu_matmul_Matmul5_64_128_8_8(): 1243.0011024037947
# wgpu_matmul_Matmul5_32_32(_Prefetch): 947.7812367484665
# wgpu_matmul_Matuml5_64_128(): 809.7130312753419
# wgpu_matmul_Matmul7_tranposedA: 736.4470849141494
# wgpu_matmul_Matmul5_32_32(): 734.6157975135544
# wgpu_matmul_Matmul7: 699.2223236954135
# wgpu_matmul_Matmul7_tranposedB: 674.8918995252604
# wgpu_matmul_Matmul5_16_16_tranposedB: 671.5750148720399
# wgpu_matmul_Matmul7_tranposedA_tranposedB: 668.887386628464
# wgpu_matmul_Matmul5_16_16_tranposedA_tranposedB: 668.2787560092565
# wgpu_matmul_Matmul5_16_16: 650.0133004672483
# wgpu_matmul_Matmul5_128_128(): 621.4650378921245
# wgpu_matmul_Matmul5_16_16_tranposedA: 619.4905453216562
# wgpu_matmul_Matmul5_128_128(_Prefetch): 450.7334874567739
# wgpu_matmul_Matmul1_tranposedA: 287.00181251297323
# wgpu_matmul_Matmul1: 277.21658397884573
# cpu_matmul_tranposedA_tranposedB: 150.92902260502268
# cpu_matmul: 144.78758356953495
# cpu_matmul_tranposedB: 142.4824208196434
# cpu_matmul_tranposedA: 135.56650932718713
# wgpu_matmul_Matmul1_tranposedA_tranposedB: 84.23707512526805
# wgpu_matmul_Matmul1_tranposedB: 84.14032694278458
# wgpu_matmul_Matmul5_128_128()_tranposedB: 43.15752342905865
# wgpu_matmul_Matmul5_128_128()_tranposedA_tranposedB: 43.118705952883026
# wgpu_matmul_Matmul5_128_128()_tranposedA: 42.97914710399176
#
# Group: matmul_2*(653x1536 * 1536x1536)
# (Size=None)
# wgpu_matmul_Matuml5_64_64(): 1466.9360008026379
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1443.102188628747
# wgpu_matmul_MatmulX: 1395.090449056641
# wgpu_matmul_Matmul5_32_32(): 1255.4699562352118
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1170.4592559866628
# wgpu_matmul_Matmul7: 836.0309939931553
# wgpu_matmul_Matmul5_16_16: 713.5326636731612
# wgpu_matmul_Matmul1: 328.6096334974887
# wgpu_matmul_Matmul5_32_32(_NoPadded): 247.33943753769577
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 231.56172050414852
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 112.05924023261797
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 105.32629371822343
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 91.5030342090615
# wgpu_matmul_Matmul5_64_64_8_8(): 66.90942677446581
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 64.08554421467605
# wgpu_matmul_Matmul5_128_128(_Prefetch): 60.49730806526072
# wgpu_matmul_Matuml5_64_64(_NoPadded): 59.12443899490545
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 54.881708645365
# wgpu_matmul_Matmul5_128_128(_NoPadded): 49.94808798894249
# wgpu_matmul_Matmul5_128_128(): 40.00386506354812
#
# Group: matmul_10*(4096x64 * 64x4173)
# (Size=None)
# wgpu_matmul_Matmul5_32_32(): 166.3866413324559
# wgpu_matmul_Matmul5_32_32(_Prefetch): 164.92569972075526
# wgpu_matmul_Matuml5_64_64(): 164.15120393876668
# wgpu_matmul_Matuml5_64_64(_Prefetch): 161.86034379033282
# wgpu_matmul_Matmul7: 153.12798043953308
# wgpu_matmul_Matmul5_16_16: 143.3797379196507
# wgpu_matmul_Matmul1: 124.17377467488139
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 108.3830019279766
# wgpu_matmul_Matmul5_32_32(_NoPadded): 104.9186045240959
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 73.85312500415357
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 68.64781879671402
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 57.980788777582674
# wgpu_matmul_MatmulX: 52.16462517507715
# wgpu_matmul_Matmul5_64_64_8_8(): 51.377494332070846
# wgpu_matmul_Matmul5_128_128(_Prefetch): 50.08563786085069
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 46.850145955423194
# wgpu_matmul_Matuml5_64_64(_NoPadded): 41.277960849469174
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 38.833535171086474
# wgpu_matmul_Matmul5_128_128(_NoPadded): 37.965759581425566
# wgpu_matmul_Matmul5_128_128(): 36.753933325245974
#
# Group: matmul_32*(32x2304 * 2304x5120)
# (Size=None)
# wgpu_matmul_Matmul5_32_32(): 1331.3338432082858
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1242.8594332800774
# wgpu_matmul_MatmulX: 1100.4970470696321
# wgpu_matmul_Matuml5_64_64(): 770.7432948478278
# wgpu_matmul_Matuml5_64_64(_Prefetch): 759.9874208852412
# wgpu_matmul_Matmul7: 707.9724692493008
# wgpu_matmul_Matmul5_16_16: 545.6450357428099
# wgpu_matmul_Matmul1: 295.2387466170064
# wgpu_matmul_Matmul5_32_32(_NoPadded): 247.9356699307449
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 241.824908699532
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 173.43292329778023
# wgpu_matmul_Matuml5_64_64(_NoPadded): 136.0325294736752
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 119.885674512707
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 111.4081283735765
# wgpu_matmul_Matmul5_128_128(_NoPadded): 102.27462201625971
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 85.87432977357774
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 55.88933434840492
# wgpu_matmul_Matmul5_64_64_8_8(): 34.377484483857025
# wgpu_matmul_Matmul5_128_128(_Prefetch): 16.915085843040515
# wgpu_matmul_Matmul5_128_128(): 11.929620984984966
#
# Group: matmul_20*(1024x64 * 64x1101)
# (Size=None)
# wgpu_matmul_Matmul5_32_32(): 821.5366481220208
# wgpu_matmul_Matmul5_32_32(_Prefetch): 791.4476742718065
# wgpu_matmul_Matuml5_64_64(_Prefetch): 598.6551897043339
# wgpu_matmul_Matuml5_64_64(): 596.1689039284274
# wgpu_matmul_Matmul7: 448.5413879063876
# wgpu_matmul_Matmul5_16_16: 376.828808019772
# wgpu_matmul_Matmul1: 251.0868748263489
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 177.3699696444163
# wgpu_matmul_Matmul5_32_32(_NoPadded): 174.8195637393339
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 69.25179766525761
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 69.04497283386742
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 66.4184212854047
# wgpu_matmul_Matmul5_64_64_8_8(): 53.42094485040979
# wgpu_matmul_Matmul5_128_128(_Prefetch): 47.61652027986738
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 47.323168471338654
# wgpu_matmul_MatmulX: 45.753137739777934
# wgpu_matmul_Matuml5_64_64(_NoPadded): 39.18608035985902
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 37.26612445689717
# wgpu_matmul_Matmul5_128_128(_NoPadded): 35.10204914605992
# wgpu_matmul_Matmul5_128_128(): 34.792462199907554
#
# Group: matmul_full
# (Size=1)
# cpu_matmul: 0.000778864618550837
# wgpu_matmul_Matmul1: 0.0002213260461926545
# wgpu_matmul_Matmul7: 0.0001812647258381828
# wgpu_matmul_MatmulX: 0.0001761507871697313
# wgpu_matmul: 0.00017589371201619556
# wgpu_matmul_Matmul5_32_32(_NoPadded): 0.00011041849708368171
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 0.00010941720227137951
# wgpu_matmul_Matuml5_64_64(_NoPadded): 0.00010941513668440676
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 9.470221908197246e-05
# wgpu_matmul_Matmul5_128_128(_NoPadded): 9.350274941945321e-05
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 8.067638847937387e-05
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 7.221750410931799e-05
# wgpu_matmul_Matmul5_16_16: 5.652976069743043e-05
# wgpu_matmul_Matmul5_32_32(): 5.4491955363926184e-05
# wgpu_matmul_Matuml5_64_64(): 5.0694161402456056e-05
# wgpu_matmul_Matmul5_32_32(_Prefetch): 4.2139186648608784e-05
# wgpu_matmul_Matmul5_64_64_8_8(): 4.141827972698167e-05
# wgpu_matmul_Matuml5_64_64(_Prefetch): 4.081628747014943e-05
# wgpu_matmul_Matuml5_64_128(): 3.82192048079673e-05
# wgpu_matmul_Matmul5_64_128_8_8(): 3.7713803919794656e-05
# wgpu_matmul_Matmul5_128_128(): 2.9316356298221777e-05
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 2.213550367214503e-05
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 2.1243896035714562e-05
# wgpu_matmul_Matmul5_128_128(_Prefetch): 1.9763050712333066e-05

# %%
print_best_results(data, 9)
# Out:
# Group: matmul_(24x1536 * 1536x6144)
#
# Group: matmul_m_1
# (Size=2048)
# wgpu_matmul_Matmul5_16_16: 27.553693415204595
# wgpu_matmul_Matmul5_16_64(): 25.74192547476765
# wgpu_matmul: 24.24842933111788
# wgpu_matmul_Matmul1: 23.879218836428457
# wgpu_matmul_Matmul7: 22.59946910203689
# wgpu_matmul_Matmul5_32_32(): 22.04527462708373
# cpu_matmul: 21.3154725758459
# wgpu_matmul_Matmul5_1_128(): 18.173622091670566
# wgpu_matmul_Matmul5_16_64(_LoadB): 16.25266185948022
# wgpu_matmul_Matuml5_64_64(): 13.554887091587627
# wgpu_matmul_Matmul5_1_128(_LoadB): 11.787527517478617
# wgpu_matmul_Matmul5_16_64(_Prefetch_LoadB): 11.480629516414767
# wgpu_matmul_Matmul5_1_128(_Prefetch): 11.322072233944004
# wgpu_matmul_Matmul5_1_128(_Prefetch_LoadB): 9.997974061002813
# wgpu_matmul_Matmul5_64_64_8_8(): 8.936843476852262
# wgpu_matmul_Matmul5_128_128(): 5.826312281347342
# wgpu_matmul_Matmul5_1_128(_NoPadded): 5.523290747217718
# wgpu_matmul_Matmul5_1_128(_Prefetch_NoPadded): 5.417819124550855
# wgpu_matmul_Matmul5_16_64(_NoPadded_LoadB): 5.029895700910091
# wgpu_matmul_Matmul5_16_64(_Prefetch_NoPadded_LoadB): 4.860490350862696
# wgpu_matmul_Matmul5_1_128(_NoPadded_LoadB): 4.7264659476092845
# wgpu_matmul_Matmul5_1_128(_Prefetch_NoPadded_LoadB): 4.701171244039152
# wgpu_matmul_Matmul5_32_32(_LoadB): 3.584865679781798
#
# Group: matmul_64*(64x1664 * 1664x2560)
#
# Group: matmul_48*(24x1536 * 1536x6144)
#
# Group: matmul_(2048x2048 * 2048x2048)
#
# Group: matmul_(32x2304 * 2304x5120)
#
# Group: matmul_(1101x1280 * 1280x1280)
#
# Group: matmul_(64x2304 * 2304x5120)
#
# Group: matmul_2*(653x1536 * 1536x1536)
#
# Group: matmul_10*(4096x64 * 64x4173)
#
# Group: matmul_32*(32x2304 * 2304x5120)
#
# Group: matmul_20*(1024x64 * 64x1101)
#
# Group: matmul_full
# (Size=2048)
# wgpu_matmul_Matmul5_64_64_8_8(): 2547.42775758005
# wgpu_matmul_MatmulX: 2423.5265530997913
# wgpu_matmul: 2366.9552784753805
# wgpu_matmul_Matmul5_64_128_8_8(): 1690.0579190726744
# wgpu_matmul_Matmul5_128_128(): 1582.0097221361325
# wgpu_matmul_Matuml5_64_64(_Prefetch): 1495.4746257240859
# wgpu_matmul_Matuml5_64_64(): 1455.8242165590323
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch): 1408.1727730221112
# wgpu_matmul_Matmul5_128_128(_Prefetch): 1341.0020697876685
# wgpu_matmul_Matmul5_32_32(_Prefetch): 1148.1836853251
# wgpu_matmul_Matuml5_64_128(): 1112.4078836114963
# wgpu_matmul_Matmul5_32_32(): 983.0571975664786
# wgpu_matmul_Matmul7: 830.4727540035803
# wgpu_matmul_Matmul5_16_16: 818.1222043949998
# wgpu_matmul_Matmul1: 315.3991972955873
# cpu_matmul: 298.5351778447156
# wgpu_matmul_Matmul5_32_32(_NoPadded): 232.16598283320164
# wgpu_matmul_Matmul5_32_32(_Prefetch_NoPadded): 226.2486918613887
# wgpu_matmul_Matmul5_64_64_8_8(_Prefetch_NoPadded): 105.85357919523865
# wgpu_matmul_Matuml5_64_64(_Prefetch_NoPadded): 86.36282551733024
# wgpu_matmul_Matmul5_128_128(_Prefetch_NoPadded): 65.39976504251256
# wgpu_matmul_Matuml5_64_64(_NoPadded): 61.59848546170106
# wgpu_matmul_Matmul5_64_64_8_8(_NoPadded): 54.88009989340346
# wgpu_matmul_Matmul5_128_128(_NoPadded): 50.57251937843016

# %%
FLOPS = 2048 * 2048 * 2048
B = 2048*2048*2
#t2 = FLOPS / 1608.0 + (B) / x = FLOPS / 1044.77

x =  B / (FLOPS / 1044.77 - FLOPS / 1608.0) 
print(x)



t = FLOPS / 1608.0 + B / x 
print(t)

t2 = FLOPS / 1044.77
print(t2)
# Out:
# 2.912869326252153
# 8221842.694564354
# 8221842.694564354
